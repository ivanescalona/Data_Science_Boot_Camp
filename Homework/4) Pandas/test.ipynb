# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(pd.read_csv('purchase_data.csv'))

# %%
df[df["SN"]=="Haillyrgue51"]
# Out:
#      Purchase ID            SN  Age Gender  Item ID              Item Name  \
# 33            33  Haillyrgue51    7   Male       44  Bonecarvin Battle Axe
# 78            78  Haillyrgue51    7   Male       50                   Dawn
# 515          515  Haillyrgue51    7   Male       40          Second Chance
#
#      Price
# 33    2.38
# 78    4.60
# 515   2.52

# %%
df.head(3)
# Out:
#    Purchase ID           SN  Age Gender  Item ID  \
# 0            0      Lisim78   20   Male      108
# 1            1  Lisovynya38   40   Male      143
# 2            2   Ithergue48   24   Male       92
#
#                                    Item Name  Price
# 0  Extraction, Quickblade Of Trembling Hands   3.53
# 1                          Frenzied Scimitar   1.56
# 2                               Final Critic   4.88

# %%
player_num1 = df['Purchase ID'].count()
player_num1
# Out:
# 780

# %%
player_num2 = len(df['SN'].unique())
player_num2
# Out:
# 576

# %%
unique_items = len(df['Item Name'].unique())
unique_items
# Out:
# 179

# %%
price_df = pd.DataFrame(df['Price'].unique())

# %%
total_mean = df['Price'].mean()
total_mean
# Out:
# 3.050987179487176

# %%
unique_price_mean = df['Price'].unique().mean()
print(np.average(unique_price_mean))
# Out:
# 3.0322068965517244

# %%
total_revenue = df['Price'].sum()
total_revenue
# Out:
# 2379.77

# %%
df_unique_names = pd.DataFrame(df['SN'].unique())
df_unique_names.head(5)
# Out:
#                0
# 0        Lisim78
# 1    Lisovynya38
# 2     Ithergue48
# 3  Chamassasya86
# 4      Iskosia90

# %%
male_players = len(df['SN'].loc[df['Gender'] == 'Male'].unique())
male_players
# Out:
# 484

# %%
female_players = len(df['SN'].loc[df['Gender'] == 'Female'].unique())
female_players
# Out:
# 81

# %%
other_players = len(df['SN'].loc[(df['Gender'] != 'Female') & (df['Gender'] != 'Male')].unique())
other_players
# Out:
# 11

# %%
percent_m = male_players/player_num2
print(percent_m)

percent_f = female_players/player_num2
print(percent_f)

percent_o = other_players/player_num2
print(percent_o)
# Out:
# 0.8402777777777778
# 0.140625
# 0.019097222222222224

# %%
percent_f+percent_m+percent_o
# Out:
# 1.0

# %%
df.groupby('Gender').count()
# Out:
#                        Purchase ID   SN  Age  Item ID  Item Name  Price
# Gender
# Female                         113  113  113      113        113    113
# Male                           652  652  652      652        652    652
# Other / Non-Disclosed           15   15   15       15         15     15

# %%
df.groupby('Gender').mean()
# Out:
#                        Purchase ID        Age    Item ID     Price
# Gender
# Female                  379.380531  21.345133  85.477876  3.203009
# Male                    392.516871  22.917178  93.524540  3.017853
# Other / Non-Disclosed   334.600000  24.200000  80.800000  3.346000

# %%
df.groupby('Gender').sum()
# Out:
#                        Purchase ID    Age  Item ID    Price
# Gender
# Female                       42870   2412     9659   361.94
# Male                        255921  14942    60978  1967.64
# Other / Non-Disclosed         5019    363     1212    50.19

# %%
df.groupby(['Gender', 'SN']).mean().head()
# Out:
#                       Purchase ID   Age  Item ID  Price
# Gender SN
# Female Adastirin33          142.0  35.0    175.0   4.48
#        Aerithllora36        426.0  29.0    117.5   4.32
#        Aethedru70           775.0  21.0     60.0   3.54
#        Aidain51             516.0  39.0     35.0   3.45
#        Aiduesu86            429.0  22.0    179.0   4.48

# %%
male_df = df.loc[df['Gender'] == 'Male']

# %%
bins = [0,9,14,19,24,29,34,39,150]
bins_label = ['<10', '10-14', '15-19', '20-24', '25-29', '30-34', '35-39', '40+']

# %%
df['Age Groups'] = pd.cut(df["Age"], bins, labels= bins_label, right = True)
df
# Out:
#      Purchase ID               SN  Age                 Gender  Item ID  \
# 0              0          Lisim78   20                   Male      108
# 1              1      Lisovynya38   40                   Male      143
# 2              2       Ithergue48   24                   Male       92
# 3              3    Chamassasya86   24                   Male      100
# 4              4        Iskosia90   23                   Male      131
# 5              5          Yalae81   22                   Male       81
# 6              6        Itheria73   36                   Male      169
# 7              7      Iskjaskst81   20                   Male      162
# 8              8        Undjask33   22                   Male       21
# 9              9      Chanosian48   35  Other / Non-Disclosed      136
# 10            10        Inguron55   23                   Male       95
# 11            11     Haisrisuir60   23                   Male      162
# ...

# %%
df_unique = df.set_index('Purchase ID', inplace = False)

# %%
df_unique = pd.DataFrame(df['SN'].unique())
df_unique
# Out:
#                   0
# 0           Lisim78
# 1       Lisovynya38
# 2        Ithergue48
# 3     Chamassasya86
# 4         Iskosia90
# 5           Yalae81
# 6         Itheria73
# 7       Iskjaskst81
# 8         Undjask33
# 9       Chanosian48
# 10        Inguron55
# 11     Haisrisuir60
# 12     Saelaephos52
# 13      Assjaskan73
# 14      Saesrideu94
# 15        Lisassa64
# 16        Lisirra25
# 17        Zontibe81
# 18        Reunasu60
# 19        Chamalo71
# 20     Iathenudil29
# 21    Phiarithdeu40
# 22     Siarithria38
# 23         Eyrian71
# 24          Siala43
# 25        Lisirra87
# 26       Lirtossa84
# 27          Eusri44
# 28           Aela59
# 29          Tyida79
# ..              ...
# 546    Chanosiaya39
# 547       Assylla81
# 548       Aidaira26
# 549        Eudanu84
# 550      Chamiman85
# 551     Tyialisti80
# 552       Marundi65
# 553         Eusur90
# 554   Mindirranya33
# 555    Phiallylis33
# 556          Isty55
# 557     Frichilsa31
# 558      Chanista95
# ...

# %%
df.groupby('Age Groups').count()
# Out:
#             Purchase ID   SN  Age  Gender  Item ID  Item Name  Price
# Age Groups
# <10                  23   23   23      23       23         23     23
# 10-14                28   28   28      28       28         28     28
# 15-19               136  136  136     136      136        136    136
# 20-24               365  365  365     365      365        365    365
# 25-29               101  101  101     101      101        101    101
# 30-34                73   73   73      73       73         73     73
# 35-39                41   41   41      41       41         41     41
# 40+                  13   13   13      13       13         13     13

# %%
df.groupby('Age Groups').sum()['Price']
# Out:
# Age Groups
# <10        77.13
# 10-14      82.78
# 15-19     412.89
# 20-24    1114.06
# 25-29     293.00
# 30-34     214.00
# 35-39     147.67
# 40+        38.24
# Name: Price, dtype: float64

# %%
df.groupby('Age Groups').mean()['Price']
# Out:
# Age Groups
# <10      3.353478
# 10-14    2.956429
# 15-19    3.035956
# 20-24    3.052219
# 25-29    2.900990
# 30-34    2.931507
# 35-39    3.601707
# 40+      2.941538
# Name: Price, dtype: float64

# %%
df_age = df[['SN', 'Age', 'Age Groups', 'Price']].set_index('SN')
df_age
# Out:
#                  Age Age Groups  Price
# SN
# Lisim78           20      20-24   3.53
# Lisovynya38       40        40+   1.56
# Ithergue48        24      20-24   4.88
# Chamassasya86     24      20-24   3.27
# Iskosia90         23      20-24   1.44
# Yalae81           22      20-24   3.61
# Itheria73         36      35-39   2.18
# Iskjaskst81       20      20-24   2.67
# Undjask33         22      20-24   1.10
# Chanosian48       35      35-39   3.58
# Inguron55         23      20-24   4.74
# Haisrisuir60      23      20-24   2.67
# Saelaephos52      21      20-24   4.18
# Assjaskan73       22      20-24   1.70
# Saesrideu94       35      35-39   4.86
# Lisassa64         21      20-24   2.89
# Lisirra25         20      20-24   2.52
# Zontibe81         21      20-24   1.76
# Reunasu60         22      20-24   4.90
# Chamalo71         30      30-34   4.64
# Iathenudil29      20      20-24   4.60
# Phiarithdeu40     20      20-24   1.48
# Siarithria38      38      35-39   3.81
# ...

# %%
df_age.groupby(['Age Groups', 'SN'])['Price'].mean()
# Out:
# Age Groups  SN
# <10         Anallorgue57     2.850000
#             Chadjask77       4.930000
#             Chanossast57     4.320000
#             Eurithphos97     2.275000
#             Eusri44          3.090000
#             Frichossala54    3.080000
#             Haillyrgue51     3.166667
#             Heudai45         3.470000
#             Ililsan66        2.850000
#             Ilmol66          3.085000
#             Quaecjask96      4.400000
#             Quilassa66       4.230000
#             Seuthep89        2.050000
#             Sisur91          4.190000
#             Sondadar26       3.235000
#             Sondossa69       4.480000
#             Tyeurith29       3.650000
# 10-14       Aeralria27       4.090000
#             Aillyrin83       2.890000
#             Chanirrasta87    4.940000
#             Eosurdru76       1.790000
#             Ethralista69     2.220000
#             Iana95           3.100000
#             Iarilis73        2.745000
# ...

# %%
df_top_spenders = df.groupby('SN').sum()

# %%
df_top5_spenders = df_top_spenders.sort_values('Price', ascending = False).head()
df_top5_spenders
# Out:
#              Purchase ID  Age  Item ID  Price
# SN
# Lisosia93           1630  125      451  18.96
# Idastidru52         1999   96      527  15.45
# Chamjask73          1306   66      339  13.83
# Iral74              2285   84      518  13.62
# Iskadarya95          713   60      321  13.10

# %%
df_top_items = df.groupby('Item Name').count()

# %%
df_top5_items = df_top_items.sort_values('Item ID', ascending= False).head()

# %%
df_top5_items
# Out:
#                                               Purchase ID  SN  Age  Gender  \
# Item Name
# Final Critic                                           13  13   13      13
# Oathbreaker, Last Hope of the Breaking Storm           12  12   12      12
# Persuasion                                              9   9    9       9
# Nirvana                                                 9   9    9       9
# Extraction, Quickblade Of Trembling Hands               9   9    9       9
#
#                                               Item ID  Price  Age Groups
# Item Name
# Final Critic                                       13     13          13
# Oathbreaker, Last Hope of the Breaking Storm       12     12          12
# Persuasion                                          9      9           9
# Nirvana                                             9      9           9
# Extraction, Quickblade Of Trembling Hands           9      9           9

# %%
df_best_seller = df.groupby(['Item ID', 'Item Name']).sum()
df_best5_seller = df_best_seller.sort_values('Price', ascending = False).head()

# %%
df_best5_seller
# Out:
#                                                       Purchase ID  Age  Price
# Item ID Item Name
# 178     Oathbreaker, Last Hope of the Breaking Storm         4960  287  50.76
# 82      Nirvana                                              2761  215  44.10
# 145     Fiery Glass Crusader                                 4345  187  41.22
# 92      Final Critic                                         3773  195  39.04
# 103     Singed Scalpel                                       3947  178  34.80
