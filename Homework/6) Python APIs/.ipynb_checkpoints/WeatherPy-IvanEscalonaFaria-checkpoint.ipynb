# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Import funciton that converts Unix Time Stamp into convencional date format
from get_date_from_unix import get_date_from_unix

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = list(zip(lats, lngs))

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 649

# %%
cities
# Out:
# ['dikson',
#  'tuktoyaktuk',
#  'nalut',
#  'novopavlovka',
#  'hermanus',
#  'hobart',
#  'vaini',
#  'ushuaia',
#  'thompson',
#  'roebourne',
#  'basoko',
#  'praia da vitoria',
#  'kirakira',
#  'alegrete',
#  'glarus',
#  'valparaiso',
#  'verkhnetulomskiy',
#  'chinsali',
#  'flinders',
#  'avarua',
#  'kamenskoye',
#  'nizhniy ingash',
#  'albany',
#  'samarai',
#  'busselton',
#  'puerto ayora',
#  'camacha',
#  'coolum beach',
#  'jamestown',
#  'attawapiskat',
#  'hailar',
#  'rikitea',
#  'bluff',
#  'port alfred',
#  'bilibino',
#  'izumo',
#  'vostok',
#  'nurota',
#  'ikalamavony',
#  'cherskiy',
#  'ambon',
#  'guaymas',
#  'semenivka',
#  'shakawe',
#  'mahebourg',
#  'poum',
#  'saskylakh',
#  'belushya guba',
#  'acarau',
#  'bambous virieux',
#  'ecoporanga',
#  'namatanai',
#  'dawson creek',
#  'cape town',
#  'ancud',
#  'kodiak',
#  'sobolevo',
#  'new norfolk',
#  'palmas',
#  'kavieng',
#  'balikpapan',
#  'tiksi',
#  'zyryanka',
#  'washougal',
# ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"


# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
city_test_list = ['banjar', 'caravelas', 'albany', 'bekobod', 'guimar', 'kysyl-syr', 'victoria', 'cape town', 'ribeira grande', 'adrar', 'tuktoyaktuk', 'synya', 'ushuaia', 'ilinskiy', 'sentyabrskiy', 'busselton', 'nikolskoye', 'domoni']

# %%
count1 = 0
count2 = 0
city_main_dict = dict()
new_dict = dict()
print('Beginning Data Retrieval\n-----------------------------')
for city in city_test_list:
    city_dict = dict()
    temp_dict = dict()
    count1 +=1
    try:
        temp_city = requests.get(query_url+city).json()
        city_dict['City'] = city
        city_dict['Cloudiness'] = list(temp_city['clouds'].values())[0]
        city_dict['Country'] = temp_city['sys']['country']
        city_dict['Date'] = get_date_from_unix(temp_city['dt'])
        city_dict['Humidity'] = temp_city['main']['humidity']
        city_dict['Latitude'] = lat_lngs[count1][0]
        city_dict['Longitude'] = lat_lngs[count1][1]
        city_dict['Max Temperature (°F)'] = temp_city['main']['temp_max']
        city_dict['Wind Speed(mph)'] = temp_city['wind']['speed']
        city_main_dict[count2] = city_dict
        print('Processing Record ' + str(count2+1) +  '| '+city)
        temp_dict['Date'] = temp_city['dt']
        new_dict[count2] = temp_dict
        count2 += 1
        time.sleep(1)
    except:
        print('City not found. Skipping...')
        time.sleep(1)

print('-----------------------------\nData Retrieval Completed')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1| banjar
# Processing Record 2| caravelas
# Processing Record 3| albany
# Processing Record 4| bekobod
# City not found. Skipping...
# Processing Record 5| kysyl-syr
# Processing Record 6| victoria
# Processing Record 7| cape town
# Processing Record 8| ribeira grande
# Processing Record 9| adrar
# Processing Record 10| tuktoyaktuk
# Processing Record 11| synya
# Processing Record 12| ushuaia
# Processing Record 13| ilinskiy
# City not found. Skipping...
# Processing Record 14| busselton
# Processing Record 15| nikolskoye
# City not found. Skipping...
# -----------------------------
# Data Retrieval Completed

# %%
city_test
# Out:
# {'coord': {'lon': -66.91, 'lat': 10.51},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03n'}],
#  'base': 'stations',
#  'main': {'temp': 75.94,
#   'pressure': 1011,
#   'humidity': 74,
#   'temp_min': 72,
#   'temp_max': 78.8},
#  'visibility': 10000,
#  'wind': {'speed': 3.36, 'deg': 110},
#  'clouds': {'all': 40},
#  'dt': 1554171311,
#  'sys': {'type': 1,
#   'id': 8759,
#   'message': 0.141,
#   'country': 'VE',
#   'sunrise': 1554114280,
#   'sunset': 1554158288},
#  'id': 3646738,
#  'name': 'Caracas',
#  'cod': 200}

# %%
print(city_test['main'])
print(city_test['wind'])
print(city_test['dt'])
print(list(city_test['clouds'].values())[0])
print(city_test['sys']['country'])
# Out:
# {'temp': 75.94, 'pressure': 1011, 'humidity': 74, 'temp_min': 72, 'temp_max': 78.8}
# {'speed': 3.36, 'deg': 110}
# 1554171311
# 40
# VE

# %%
lat_lngs

# %%
temp_city = requests.get(query_url+'not a city').json()
temp_city
# Out:
# {'cod': '404', 'message': 'city not found'}

# %%
new_dict
# Out:
# {0: {'Date': 1554184393},
#  1: {'Date': 1554184557},
#  2: {'Date': 1554184529},
#  3: {'Date': 1554183000},
#  4: {'Date': 1554184593},
#  5: {'Date': 1554183000},
#  6: {'Date': 1554184566},
#  7: {'Date': 1554184597},
#  8: {'Date': 1554181200},
#  9: {'Date': 1554181200},
#  10: {'Date': 1554184600},
#  11: {'Date': 1554181200},
#  12: {'Date': 1554183651},
#  13: {'Date': 1554184506},
#  14: {'Date': 1554184546}}

# %%
df = pd.DataFrame(city_main_dict).T
df
# Out:
#               City Cloudiness Country                 Date Humidity  Latitude  \
# 0           banjar         44      ID  2019-Apr-2 05:53:13       77  -82.0715
# 1        caravelas         68      BR  2019-Apr-2 05:55:57      100  -5.64293
# 2           albany         20      US  2019-Apr-2 05:55:29       53  -63.4353
# 3          bekobod          8      TJ  2019-Apr-2 05:30:00       63   -25.325
# 4        kysyl-syr         36      RU  2019-Apr-2 05:56:33       58    63.822
# 5         victoria         75      BN  2019-Apr-2 05:30:00       66   40.5957
# 6        cape town          0      ZA  2019-Apr-2 05:56:06       62  -62.3802
# 7   ribeira grande         36      PT  2019-Apr-2 05:56:37       99   82.1094
# 8            adrar          0      DZ  2019-Apr-2 05:00:00       51  -1.33408
# 9      tuktoyaktuk         75      CA  2019-Apr-2 05:00:00       77  -23.6118
# 10           synya         80      RU  2019-Apr-2 05:56:40       81   40.4767
# ...

# %%
ser = list(df.columns)
ser.pop(0)
ser.pop(1)
ser.pop(1)
ser

for column in ser:
    df[column] = pd.to_numeric(df[column])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15 entries, 0 to 14
# Data columns (total 9 columns):
# City                    15 non-null object
# Cloudiness              15 non-null int64
# Country                 15 non-null object
# Date                    15 non-null object
# Humidity                15 non-null int64
# Latitude                15 non-null float64
# Longitude               15 non-null float64
# Max Temperature (°F)    15 non-null float64
# Wind Speed(mph)         15 non-null float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 1020.0+ bytes

# %%
get_date_from_unix(1554181200)
# Out:
# '2019-Apr-2 05:00:00'

# %%
from datetime import datetime
datetime.utcfromtimestamp(1554181200).strftime('%Y-%b-%d %H:%M:%S')
# Out:
# '2019-Apr-02 05:00:00'

# %%
df.to_csv(output_data_file)

# %%
df.columns
# Out:
# Index(['City', 'Cloudiness', 'Country', 'Date', 'Humidity', 'Latitude',
#        'Longitude', 'Max Temperature (°F)', 'Wind Speed(mph)'],
#       dtype='object')

# %%
my_dict = dict()
for column in df.columns:
    my_dict[column] = df[column].count()

pd.Series(my_dict)
# Out:
# City                    15
# Cloudiness              15
# Country                 15
# Date                    15
# Humidity                15
# Latitude                15
# Longitude               15
# Max Temperature (°F)    15
# Wind Speed(mph)         15
# dtype: int64

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
df.plot('Latitude', 'Max Temperature (°F)', 'Scatter')

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
df.plot('Latitude', 'Humidity', 'Scatter')

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
df.plot('Latitude', 'Cloudiness', 'Scatter')

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
df.plot('Latitude', 'Wind Speed(mph)', 'Scatter')
