# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Import funciton that converts Unix Time Stamp into convencional date format
from get_date_from_unix import get_date_from_unix

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = list(zip(lats, lngs))

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 611

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"


# Build partial query URL
query_url = f"{url}appid={api_key}&units={units}&q="

# %%
#Initialize variables for the for loop
count = 0
city_main_dict = dict()


#Text
print('Beginning Data Retrieval\n-----------------------------')

for city in cities:
    #Initialize temporary variables that will hold the data
    city_dict = dict()
    
    
    #Exception handling
    try:
        #output text to inform user which record is being processed
        print('Processing Record ' + str(count+1) +  '| '+city + '|', end = " ")
        
        #request to Openweather API - Conversion into Json object, storing it in temporary dictionary
        temp_city = requests.get(query_url+city).json()
        
        #Storing relevant data into temporary dictionary
        city_dict['City'] = city
        city_dict['Cloudiness (%)'] = list(temp_city['clouds'].values())[0]
        city_dict['Country'] = temp_city['sys']['country']
        city_dict['Date'] = get_date_from_unix(temp_city['dt'])
        city_dict['Humidity (%)'] = temp_city['main']['humidity']
        city_dict['Latitude'] = temp_city['coord']['lat']
        city_dict['Longitude'] = temp_city['coord']['lon']
        city_dict['Max Temperature (°F)'] = temp_city['main']['temp_max']
        city_dict['Wind Speed(mph)'] = temp_city['wind']['speed']
        city_main_dict[count] = city_dict
                
        #update counter for loop
        count += 1
        print('Record ' + str(count) +  ' successfully processed.')
        #Allows a wait time of 0.5 seconds in between loop iterations because of the restriction in number of requests allowed by the Open Weather API
        time.sleep(0.5)
    except:
        
        print(f'{city} not found or there was a problem with record #{count+1}. Skipping...')
        
        #update counter for loop
        count += 1
        
        #Allows a wait time of 0.5 seconds in between loop iterations because of the restriction in number of requests allowed by the Open Weather API
        time.sleep(0.5)
        
        

print('-----------------------------\nData Retrieval Completed')
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1| kununurra| Record 1 successfully processed.
# Processing Record 2| tigzirt| Record 2 successfully processed.
# Processing Record 3| rikitea| Record 3 successfully processed.
# Processing Record 4| arraial do cabo| Record 4 successfully processed.
# Processing Record 5| mataura| Record 5 successfully processed.
# Processing Record 6| ushuaia| Record 6 successfully processed.
# Processing Record 7| norman wells| Record 7 successfully processed.
# Processing Record 8| hermanus| Record 8 successfully processed.
# Processing Record 9| busselton| Record 9 successfully processed.
# Processing Record 10| pavlodar| Record 10 successfully processed.
# Processing Record 11| tiksi| Record 11 successfully processed.
# Processing Record 12| talnakh| Record 12 successfully processed.
# Processing Record 13| nouadhibou| Record 13 successfully processed.
# Processing Record 14| torbay| Record 14 successfully processed.
# Processing Record 15| nguiu| nguiu not found or there was a problem with record #15. Skipping...
# Processing Record 16| dudinka| Record 16 successfully processed.
# Processing Record 17| hilo| Record 17 successfully processed.
# Processing Record 18| tasiilaq| Record 18 successfully processed.
# Processing Record 19| inyonga| Record 19 successfully processed.
# Processing Record 20| saint-philippe| Record 20 successfully processed.
# Processing Record 21| illoqqortoormiut| illoqqortoormiut not found or there was a problem with record #21. Skipping...
# Processing Record 22| caravelas| Record 22 successfully processed.
# Processing Record 23| avarua| Record 23 successfully processed.
# Processing Record 24| ginir| Record 24 successfully processed.
# Processing Record 25| taolanaro| taolanaro not found or there was a problem with record #25. Skipping...
# Processing Record 26| jamestown| Record 26 successfully processed.
# Processing Record 27| kuching| Record 27 successfully processed.
# Processing Record 28| madisonville| Record 28 successfully processed.
# Processing Record 29| mys shmidta| mys shmidta not found or there was a problem with record #29. Skipping...
# Processing Record 30| jinchang| Record 30 successfully processed.
# Processing Record 31| maneadero| maneadero not found or there was a problem with record #31. Skipping...
# Processing Record 32| punta arenas| Record 32 successfully processed.
# Processing Record 33| albany| Record 33 successfully processed.
# Processing Record 34| nizhneyansk| nizhneyansk not found or there was a problem with record #34. Skipping...
# Processing Record 35| erenhot| Record 35 successfully processed.
# Processing Record 36| stornoway| stornoway not found or there was a problem with record #36. Skipping...
# Processing Record 37| chuy| Record 37 successfully processed.
# Processing Record 38| kochinda| Record 38 successfully processed.
# Processing Record 39| maragogi| Record 39 successfully processed.
# Processing Record 40| sentyabrskiy| sentyabrskiy not found or there was a problem with record #40. Skipping...
# Processing Record 41| hobart| Record 41 successfully processed.
# Processing Record 42| butaritari| Record 42 successfully processed.
# Processing Record 43| plettenberg bay| Record 43 successfully processed.
# Processing Record 44| saldanha| Record 44 successfully processed.
# Processing Record 45| ilorin| Record 45 successfully processed.
# Processing Record 46| chokurdakh| Record 46 successfully processed.
# Processing Record 47| bababe| bababe not found or there was a problem with record #47. Skipping...
# Processing Record 48| yellowknife| Record 48 successfully processed.
# Processing Record 49| xiongyue| Record 49 successfully processed.
# Processing Record 50| barrow| Record 50 successfully processed.
# Processing Record 51| amderma| amderma not found or there was a problem with record #51. Skipping...
# Processing Record 52| bredasdorp| Record 52 successfully processed.
# Processing Record 53| awjilah| Record 53 successfully processed.
# Processing Record 54| koshurnikovo| Record 54 successfully processed.
# Processing Record 55| oksfjord| Record 55 successfully processed.
# Processing Record 56| roma| Record 56 successfully processed.
# Processing Record 57| port alfred| Record 57 successfully processed.
# Processing Record 58| kyle of lochalsh| kyle of lochalsh not found or there was a problem with record #58. Skipping...
# Processing Record 59| kashi| kashi not found or there was a problem with record #59. Skipping...
# Processing Record 60| hervey bay| Record 60 successfully processed.
# Processing Record 61| georgetown| Record 61 successfully processed.
# Processing Record 62| rudbar| rudbar not found or there was a problem with record #62. Skipping...
# Processing Record 63| manggar| Record 63 successfully processed.
# Processing Record 64| qaanaaq| Record 64 successfully processed.
# Processing Record 65| sao jose da coroa grande| Record 65 successfully processed.
# Processing Record 66| new norfolk| Record 66 successfully processed.
# Processing Record 67| vieques| Record 67 successfully processed.
# Processing Record 68| oyek| Record 68 successfully processed.
# Processing Record 69| luderitz| Record 69 successfully processed.
# Processing Record 70| khovu-aksy| Record 70 successfully processed.
# Processing Record 71| lampazos de naranjo| Record 71 successfully processed.
# Processing Record 72| coos bay| Record 72 successfully processed.
# Processing Record 73| vostok| Record 73 successfully processed.
# Processing Record 74| cherskiy| Record 74 successfully processed.
# Processing Record 75| thompson| Record 75 successfully processed.
# Processing Record 76| lata| Record 76 successfully processed.
# Processing Record 77| reconquista| Record 77 successfully processed.
# Processing Record 78| henties bay| Record 78 successfully processed.
# Processing Record 79| lebu| Record 79 successfully processed.
# Processing Record 80| the pas| Record 80 successfully processed.
# Processing Record 81| bluff| Record 81 successfully processed.
# Processing Record 82| codrington| Record 82 successfully processed.
# Processing Record 83| cape town| Record 83 successfully processed.
# Processing Record 84| quatre cocos| Record 84 successfully processed.
# Processing Record 85| souillac| Record 85 successfully processed.
# Processing Record 86| ponta do sol| Record 86 successfully processed.
# Processing Record 87| saint-denis| Record 87 successfully processed.
# Processing Record 88| barentsburg| barentsburg not found or there was a problem with record #88. Skipping...
# Processing Record 89| morondava| Record 89 successfully processed.
# Processing Record 90| aliwal north| Record 90 successfully processed.
# Processing Record 91| fortuna| Record 91 successfully processed.
# Processing Record 92| samarai| Record 92 successfully processed.
# Processing Record 93| marsh harbour| Record 93 successfully processed.
# Processing Record 94| sola| Record 94 successfully processed.
# Processing Record 95| mariinsk| Record 95 successfully processed.
# Processing Record 96| ahipara| Record 96 successfully processed.
# Processing Record 97| ambulu| Record 97 successfully processed.
# Processing Record 98| east london| Record 98 successfully processed.
# Processing Record 99| belushya guba| belushya guba not found or there was a problem with record #99. Skipping...
# Processing Record 100| colares| Record 100 successfully processed.
# Processing Record 101| kenai| Record 101 successfully processed.
# Processing Record 102| ancud| Record 102 successfully processed.
# Processing Record 103| vaini| Record 103 successfully processed.
# Processing Record 104| berlevag| Record 104 successfully processed.
# Processing Record 105| cidreira| Record 105 successfully processed.
# Processing Record 106| dikson| Record 106 successfully processed.
# Processing Record 107| karaul| karaul not found or there was a problem with record #107. Skipping...
# Processing Record 108| port said| Record 108 successfully processed.
# Processing Record 109| khuzhir| Record 109 successfully processed.
# Processing Record 110| el real de santa maria| Record 110 successfully processed.
# Processing Record 111| kaitangata| Record 111 successfully processed.
# Processing Record 112| nador| Record 112 successfully processed.
# Processing Record 113| osoyoos| Record 113 successfully processed.
# Processing Record 114| goure| Record 114 successfully processed.
# Processing Record 115| goderich| Record 115 successfully processed.
# Processing Record 116| zhigansk| Record 116 successfully processed.
# Processing Record 117| san cristobal| Record 117 successfully processed.
# Processing Record 118| fushun| Record 118 successfully processed.
# Processing Record 119| kattivakkam| Record 119 successfully processed.
# Processing Record 120| xai-xai| Record 120 successfully processed.
# Processing Record 121| pahrump| Record 121 successfully processed.
# Processing Record 122| srednekolymsk| Record 122 successfully processed.
# Processing Record 123| fukue| Record 123 successfully processed.
# Processing Record 124| mapiri| Record 124 successfully processed.
# Processing Record 125| bandarbeyla| Record 125 successfully processed.
# Processing Record 126| portland| Record 126 successfully processed.
# Processing Record 127| kiruna| Record 127 successfully processed.
# Processing Record 128| anchorage| Record 128 successfully processed.
# Processing Record 129| kosh-agach| Record 129 successfully processed.
# Processing Record 130| tsihombe| tsihombe not found or there was a problem with record #130. Skipping...
# Processing Record 131| blythe| Record 131 successfully processed.
# Processing Record 132| dubai| Record 132 successfully processed.
# Processing Record 133| kegayli| kegayli not found or there was a problem with record #133. Skipping...
# Processing Record 134| clyde river| Record 134 successfully processed.
# Processing Record 135| turukhansk| Record 135 successfully processed.
# Processing Record 136| sitka| Record 136 successfully processed.
# Processing Record 137| alofi| Record 137 successfully processed.
# Processing Record 138| mangrol| Record 138 successfully processed.
# Processing Record 139| sarahan| Record 139 successfully processed.
# Processing Record 140| ngukurr| ngukurr not found or there was a problem with record #140. Skipping...
# Processing Record 141| nabire| Record 141 successfully processed.
# Processing Record 142| atuona| Record 142 successfully processed.
# Processing Record 143| avera| Record 143 successfully processed.
# Processing Record 144| maceio| Record 144 successfully processed.
# Processing Record 145| lasa| Record 145 successfully processed.
# Processing Record 146| lompoc| Record 146 successfully processed.
# Processing Record 147| kailua| Record 147 successfully processed.
# Processing Record 148| khatanga| Record 148 successfully processed.
# Processing Record 149| asau| asau not found or there was a problem with record #149. Skipping...
# Processing Record 150| kapaa| Record 150 successfully processed.
# Processing Record 151| berdyuzhye| berdyuzhye not found or there was a problem with record #151. Skipping...
# Processing Record 152| chirongui| Record 152 successfully processed.
# Processing Record 153| churapcha| Record 153 successfully processed.
# Processing Record 154| mar del plata| Record 154 successfully processed.
# Processing Record 155| smithers| Record 155 successfully processed.
# Processing Record 156| saint george| Record 156 successfully processed.
# Processing Record 157| terney| Record 157 successfully processed.
# Processing Record 158| beya| Record 158 successfully processed.
# Processing Record 159| lincoln| Record 159 successfully processed.
# Processing Record 160| trimbak| Record 160 successfully processed.
# Processing Record 161| lagoa| Record 161 successfully processed.
# Processing Record 162| at-bashi| Record 162 successfully processed.
# Processing Record 163| toktogul| Record 163 successfully processed.
# Processing Record 164| bukama| Record 164 successfully processed.
# Processing Record 165| flinders| Record 165 successfully processed.
# Processing Record 166| muscat| Record 166 successfully processed.
# Processing Record 167| aykhal| Record 167 successfully processed.
# Processing Record 168| ayia anna| Record 168 successfully processed.
# Processing Record 169| mackenzie| Record 169 successfully processed.
# Processing Record 170| hamilton| Record 170 successfully processed.
# Processing Record 171| biltine| Record 171 successfully processed.
# Processing Record 172| warrnambool| Record 172 successfully processed.
# Processing Record 173| saint-gabriel| Record 173 successfully processed.
# Processing Record 174| upernavik| Record 174 successfully processed.
# Processing Record 175| lexington| Record 175 successfully processed.
# Processing Record 176| narsaq| Record 176 successfully processed.
# Processing Record 177| grindavik| Record 177 successfully processed.
# Processing Record 178| cabo san lucas| Record 178 successfully processed.
# Processing Record 179| sari| Record 179 successfully processed.
# Processing Record 180| sabang| Record 180 successfully processed.
# Processing Record 181| tabou| Record 181 successfully processed.
# Processing Record 182| visby| Record 182 successfully processed.
# Processing Record 183| attawapiskat| attawapiskat not found or there was a problem with record #183. Skipping...
# Processing Record 184| dakar| Record 184 successfully processed.
# Processing Record 185| bunol| Record 185 successfully processed.
# Processing Record 186| guerrero negro| Record 186 successfully processed.
# Processing Record 187| ribeira grande| Record 187 successfully processed.
# Processing Record 188| los llanos de aridane| Record 188 successfully processed.
# Processing Record 189| north bend| Record 189 successfully processed.
# Processing Record 190| nicoya| Record 190 successfully processed.
# Processing Record 191| tuatapere| Record 191 successfully processed.
# Processing Record 192| ilebo| Record 192 successfully processed.
# Processing Record 193| samusu| samusu not found or there was a problem with record #193. Skipping...
# Processing Record 194| isangel| Record 194 successfully processed.
# Processing Record 195| sorland| Record 195 successfully processed.
# Processing Record 196| matadi| Record 196 successfully processed.
# Processing Record 197| alice springs| Record 197 successfully processed.
# Processing Record 198| nanortalik| Record 198 successfully processed.
# Processing Record 199| aguimes| Record 199 successfully processed.
# Processing Record 200| toliary| toliary not found or there was a problem with record #200. Skipping...
# Processing Record 201| provideniya| Record 201 successfully processed.
# Processing Record 202| tessalit| Record 202 successfully processed.
# Processing Record 203| llanes| Record 203 successfully processed.
# Processing Record 204| dingle| Record 204 successfully processed.
# Processing Record 205| norden| Record 205 successfully processed.
# Processing Record 206| juba| Record 206 successfully processed.
# Processing Record 207| grand river south east| grand river south east not found or there was a problem with record #207. Skipping...
# Processing Record 208| wukari| Record 208 successfully processed.
# Processing Record 209| touros| Record 209 successfully processed.
# Processing Record 210| ostrovnoy| Record 210 successfully processed.
# Processing Record 211| imbituba| Record 211 successfully processed.
# Processing Record 212| conceicao do araguaia| Record 212 successfully processed.
# Processing Record 213| kodiak| Record 213 successfully processed.
# Processing Record 214| esperance| Record 214 successfully processed.
# Processing Record 215| paamiut| Record 215 successfully processed.
# Processing Record 216| dunedin| Record 216 successfully processed.
# Processing Record 217| alta floresta| Record 217 successfully processed.
# Processing Record 218| belgrade| Record 218 successfully processed.
# Processing Record 219| puerto carreno| Record 219 successfully processed.
# Processing Record 220| tineo| Record 220 successfully processed.
# Processing Record 221| pevek| Record 221 successfully processed.
# Processing Record 222| ilhabela| Record 222 successfully processed.
# Processing Record 223| yaroslavskaya| Record 223 successfully processed.
# Processing Record 224| lavrentiya| Record 224 successfully processed.
# Processing Record 225| zhuhai| Record 225 successfully processed.
# Processing Record 226| talas| Record 226 successfully processed.
# Processing Record 227| ayolas| Record 227 successfully processed.
# Processing Record 228| eyl| Record 228 successfully processed.
# Processing Record 229| hovd| Record 229 successfully processed.
# Processing Record 230| kloulklubed| Record 230 successfully processed.
# Processing Record 231| cabinda| Record 231 successfully processed.
# Processing Record 232| jumla| Record 232 successfully processed.
# Processing Record 233| saint-louis| Record 233 successfully processed.
# Processing Record 234| palm coast| Record 234 successfully processed.
# Processing Record 235| la palma| Record 235 successfully processed.
# Processing Record 236| jalu| Record 236 successfully processed.
# Processing Record 237| charyshskoye| Record 237 successfully processed.
# Processing Record 238| kruisfontein| Record 238 successfully processed.
# Processing Record 239| rocha| Record 239 successfully processed.
# Processing Record 240| moberly| Record 240 successfully processed.
# Processing Record 241| batagay-alyta| Record 241 successfully processed.
# Processing Record 242| port elizabeth| Record 242 successfully processed.
# Processing Record 243| turtas| Record 243 successfully processed.
# Processing Record 244| vrangel| Record 244 successfully processed.
# Processing Record 245| mana| Record 245 successfully processed.
# Processing Record 246| yablonovo| Record 246 successfully processed.
# Processing Record 247| san jose de rio tinto| Record 247 successfully processed.
# Processing Record 248| viedma| Record 248 successfully processed.
# Processing Record 249| vestmannaeyjar| Record 249 successfully processed.
# Processing Record 250| fuerte olimpo| Record 250 successfully processed.
# Processing Record 251| chunskiy| Record 251 successfully processed.
# Processing Record 252| ion corvin| Record 252 successfully processed.
# Processing Record 253| hithadhoo| Record 253 successfully processed.
# Processing Record 254| bathsheba| Record 254 successfully processed.
# Processing Record 255| oranjemund| Record 255 successfully processed.
# Processing Record 256| inhambane| Record 256 successfully processed.
# Processing Record 257| teya| Record 257 successfully processed.
# Processing Record 258| kungurtug| Record 258 successfully processed.
# Processing Record 259| puerto ayora| Record 259 successfully processed.
# Processing Record 260| bubaque| Record 260 successfully processed.
# Processing Record 261| richard toll| richard toll not found or there was a problem with record #261. Skipping...
# Processing Record 262| conde| Record 262 successfully processed.
# Processing Record 263| manadhoo| Record 263 successfully processed.
# Processing Record 264| namatanai| Record 264 successfully processed.
# Processing Record 265| wampusirpi| wampusirpi not found or there was a problem with record #265. Skipping...
# Processing Record 266| mabaruma| Record 266 successfully processed.
# Processing Record 267| bridgetown| Record 267 successfully processed.
# Processing Record 268| leningradskiy| Record 268 successfully processed.
# Processing Record 269| laichingen| Record 269 successfully processed.
# Processing Record 270| bambous virieux| Record 270 successfully processed.
# Processing Record 271| matagami| Record 271 successfully processed.
# Processing Record 272| katsuura| Record 272 successfully processed.
# Processing Record 273| omsukchan| Record 273 successfully processed.
# Processing Record 274| beringovskiy| Record 274 successfully processed.
# Processing Record 275| santa rita| Record 275 successfully processed.
# Processing Record 276| pedernales| Record 276 successfully processed.
# Processing Record 277| awbari| Record 277 successfully processed.
# Processing Record 278| castro| Record 278 successfully processed.
# Processing Record 279| dolbeau| dolbeau not found or there was a problem with record #279. Skipping...
# Processing Record 280| nhulunbuy| Record 280 successfully processed.
# Processing Record 281| clarksdale| Record 281 successfully processed.
# Processing Record 282| iquique| Record 282 successfully processed.
# Processing Record 283| tabas| Record 283 successfully processed.
# Processing Record 284| san roque| Record 284 successfully processed.
# Processing Record 285| olafsvik| olafsvik not found or there was a problem with record #285. Skipping...
# Processing Record 286| sumbawanga| Record 286 successfully processed.
# Processing Record 287| zeya| Record 287 successfully processed.
# Processing Record 288| birao| Record 288 successfully processed.
# Processing Record 289| sobolevo| Record 289 successfully processed.
# Processing Record 290| krasnyy yar| Record 290 successfully processed.
# Processing Record 291| bengkulu| bengkulu not found or there was a problem with record #291. Skipping...
# Processing Record 292| fairbanks| Record 292 successfully processed.
# Processing Record 293| vila| Record 293 successfully processed.
# Processing Record 294| tabiauea| tabiauea not found or there was a problem with record #294. Skipping...
# Processing Record 295| port-gentil| Record 295 successfully processed.
# Processing Record 296| ngama| ngama not found or there was a problem with record #296. Skipping...
# Processing Record 297| iqaluit| Record 297 successfully processed.
# Processing Record 298| hemsedal| Record 298 successfully processed.
# Processing Record 299| ha tinh| Record 299 successfully processed.
# Processing Record 300| xilagani| Record 300 successfully processed.
# Processing Record 301| saint-joseph| Record 301 successfully processed.
# Processing Record 302| elko| Record 302 successfully processed.
# Processing Record 303| katha| katha not found or there was a problem with record #303. Skipping...
# Processing Record 304| umzimvubu| umzimvubu not found or there was a problem with record #304. Skipping...
# Processing Record 305| araouane| Record 305 successfully processed.
# Processing Record 306| baden-baden| Record 306 successfully processed.
# Processing Record 307| botro| Record 307 successfully processed.
# Processing Record 308| ouadda| Record 308 successfully processed.
# Processing Record 309| pavlogradka| Record 309 successfully processed.
# Processing Record 310| kudahuvadhoo| Record 310 successfully processed.
# Processing Record 311| airai| Record 311 successfully processed.
# Processing Record 312| broken hill| Record 312 successfully processed.
# Processing Record 313| sao filipe| Record 313 successfully processed.
# Processing Record 314| baoshan| Record 314 successfully processed.
# Processing Record 315| amga| Record 315 successfully processed.
# Processing Record 316| westerly| Record 316 successfully processed.
# Processing Record 317| coihaique| Record 317 successfully processed.
# Processing Record 318| shitanjing| Record 318 successfully processed.
# Processing Record 319| muisne| Record 319 successfully processed.
# Processing Record 320| sabha| Record 320 successfully processed.
# Processing Record 321| richards bay| Record 321 successfully processed.
# Processing Record 322| muros| Record 322 successfully processed.
# Processing Record 323| ustyuzhna| Record 323 successfully processed.
# Processing Record 324| chilliwack| Record 324 successfully processed.
# Processing Record 325| grand-santi| Record 325 successfully processed.
# Processing Record 326| vila franca do campo| Record 326 successfully processed.
# Processing Record 327| prado| Record 327 successfully processed.
# Processing Record 328| nioro| Record 328 successfully processed.
# Processing Record 329| naze| Record 329 successfully processed.
# Processing Record 330| ciras| ciras not found or there was a problem with record #330. Skipping...
# Processing Record 331| general roca| Record 331 successfully processed.
# Processing Record 332| gubkinskiy| Record 332 successfully processed.
# Processing Record 333| haines junction| Record 333 successfully processed.
# Processing Record 334| saskylakh| Record 334 successfully processed.
# Processing Record 335| rio gallegos| Record 335 successfully processed.
# Processing Record 336| manado| Record 336 successfully processed.
# Processing Record 337| ukiah| Record 337 successfully processed.
# Processing Record 338| deputatskiy| Record 338 successfully processed.
# Processing Record 339| pisco| Record 339 successfully processed.
# Processing Record 340| faanui| Record 340 successfully processed.
# Processing Record 341| vaitupu| vaitupu not found or there was a problem with record #341. Skipping...
# Processing Record 342| leshukonskoye| Record 342 successfully processed.
# Processing Record 343| kahului| Record 343 successfully processed.
# Processing Record 344| galesong| Record 344 successfully processed.
# Processing Record 345| palana| Record 345 successfully processed.
# Processing Record 346| gasa| Record 346 successfully processed.
# Processing Record 347| herrenberg| Record 347 successfully processed.
# Processing Record 348| lobito| Record 348 successfully processed.
# Processing Record 349| vila velha| Record 349 successfully processed.
# Processing Record 350| burnie| Record 350 successfully processed.
# Processing Record 351| tiffin| Record 351 successfully processed.
# Processing Record 352| dauphin| Record 352 successfully processed.
# Processing Record 353| ngemplak| Record 353 successfully processed.
# Processing Record 354| hofn| Record 354 successfully processed.
# Processing Record 355| bonavista| Record 355 successfully processed.
# Processing Record 356| vadlapudi| Record 356 successfully processed.
# Processing Record 357| mokrousovo| Record 357 successfully processed.
# Processing Record 358| campos belos| Record 358 successfully processed.
# Processing Record 359| maues| Record 359 successfully processed.
# Processing Record 360| tiznit| Record 360 successfully processed.
# Processing Record 361| sayyan| Record 361 successfully processed.
# Processing Record 362| san patricio| Record 362 successfully processed.
# Processing Record 363| esil| Record 363 successfully processed.
# Processing Record 364| kurilsk| Record 364 successfully processed.
# Processing Record 365| jaicos| Record 365 successfully processed.
# Processing Record 366| tomohon| Record 366 successfully processed.
# Processing Record 367| port hardy| Record 367 successfully processed.
# Processing Record 368| neiafu| Record 368 successfully processed.
# Processing Record 369| raudeberg| Record 369 successfully processed.
# Processing Record 370| tuktoyaktuk| Record 370 successfully processed.
# Processing Record 371| conceicao da barra| Record 371 successfully processed.
# Processing Record 372| zakamensk| Record 372 successfully processed.
# Processing Record 373| geraldton| Record 373 successfully processed.
# Processing Record 374| limot| Record 374 successfully processed.
# Processing Record 375| rangkasbitung| Record 375 successfully processed.
# Processing Record 376| noumea| Record 376 successfully processed.
# Processing Record 377| praia| Record 377 successfully processed.
# Processing Record 378| mikkeli| Record 378 successfully processed.
# Processing Record 379| victoria| Record 379 successfully processed.
# Processing Record 380| hasaki| Record 380 successfully processed.
# Processing Record 381| labutta| labutta not found or there was a problem with record #381. Skipping...
# Processing Record 382| canon city| Record 382 successfully processed.
# Processing Record 383| oranjestad| Record 383 successfully processed.
# Processing Record 384| bilibino| Record 384 successfully processed.
# Processing Record 385| saint-georges| Record 385 successfully processed.
# Processing Record 386| shahdol| Record 386 successfully processed.
# Processing Record 387| ilulissat| Record 387 successfully processed.
# Processing Record 388| union| Record 388 successfully processed.
# Processing Record 389| bismarck| Record 389 successfully processed.
# Processing Record 390| sahrak| sahrak not found or there was a problem with record #390. Skipping...
# Processing Record 391| ambilobe| Record 391 successfully processed.
# Processing Record 392| sambava| Record 392 successfully processed.
# Processing Record 393| coolum beach| Record 393 successfully processed.
# Processing Record 394| kavieng| Record 394 successfully processed.
# Processing Record 395| fare| Record 395 successfully processed.
# Processing Record 396| qui nhon| qui nhon not found or there was a problem with record #396. Skipping...
# Processing Record 397| port blair| Record 397 successfully processed.
# Processing Record 398| matelandia| Record 398 successfully processed.
# Processing Record 399| kaa-khem| Record 399 successfully processed.
# Processing Record 400| coahuayana| Record 400 successfully processed.
# Processing Record 401| urumqi| urumqi not found or there was a problem with record #401. Skipping...
# Processing Record 402| luis correia| Record 402 successfully processed.
# Processing Record 403| san juan| Record 403 successfully processed.
# Processing Record 404| liku| Record 404 successfully processed.
# Processing Record 405| tumannyy| tumannyy not found or there was a problem with record #405. Skipping...
# Processing Record 406| sinnamary| Record 406 successfully processed.
# Processing Record 407| puri| Record 407 successfully processed.
# Processing Record 408| alexandria| Record 408 successfully processed.
# Processing Record 409| taoudenni| Record 409 successfully processed.
# Processing Record 410| srandakan| Record 410 successfully processed.
# Processing Record 411| aripuana| Record 411 successfully processed.
# Processing Record 412| sovetsk| Record 412 successfully processed.
# Processing Record 413| andevoranto| andevoranto not found or there was a problem with record #413. Skipping...
# Processing Record 414| skjervoy| Record 414 successfully processed.
# Processing Record 415| san matias| Record 415 successfully processed.
# Processing Record 416| ugoofaaru| Record 416 successfully processed.
# Processing Record 417| tommot| Record 417 successfully processed.
# Processing Record 418| severnoye| Record 418 successfully processed.
# Processing Record 419| marsa matruh| Record 419 successfully processed.
# Processing Record 420| kapoeta| kapoeta not found or there was a problem with record #420. Skipping...
# Processing Record 421| vallenar| Record 421 successfully processed.
# Processing Record 422| armacao dos buzios| armacao dos buzios not found or there was a problem with record #422. Skipping...
# Processing Record 423| lewiston| Record 423 successfully processed.
# Processing Record 424| black river| Record 424 successfully processed.
# Processing Record 425| caceres| Record 425 successfully processed.
# Processing Record 426| sorong| Record 426 successfully processed.
# Processing Record 427| bella union| Record 427 successfully processed.
# Processing Record 428| andrelandia| andrelandia not found or there was a problem with record #428. Skipping...
# Processing Record 429| warqla| warqla not found or there was a problem with record #429. Skipping...
# Processing Record 430| silvan| Record 430 successfully processed.
# Processing Record 431| yar-sale| Record 431 successfully processed.
# Processing Record 432| cordele| Record 432 successfully processed.
# Processing Record 433| xining| Record 433 successfully processed.
# Processing Record 434| baker city| Record 434 successfully processed.
# Processing Record 435| mishan| Record 435 successfully processed.
# Processing Record 436| el rusio| Record 436 successfully processed.
# Processing Record 437| inongo| Record 437 successfully processed.
# Processing Record 438| kiunga| Record 438 successfully processed.
# Processing Record 439| laredo| Record 439 successfully processed.
# Processing Record 440| komsomolskiy| Record 440 successfully processed.
# Processing Record 441| olinda| Record 441 successfully processed.
# Processing Record 442| marawi| Record 442 successfully processed.
# Processing Record 443| seydi| Record 443 successfully processed.
# Processing Record 444| itoman| Record 444 successfully processed.
# Processing Record 445| hirara| Record 445 successfully processed.
# Processing Record 446| banjarmasin| Record 446 successfully processed.
# Processing Record 447| cap-aux-meules| Record 447 successfully processed.
# Processing Record 448| korla| korla not found or there was a problem with record #448. Skipping...
# Processing Record 449| salinopolis| Record 449 successfully processed.
# Processing Record 450| kaabong| Record 450 successfully processed.
# Processing Record 451| zainsk| Record 451 successfully processed.
# Processing Record 452| chapais| Record 452 successfully processed.
# Processing Record 453| songjianghe| Record 453 successfully processed.
# Processing Record 454| marrakesh| Record 454 successfully processed.
# Processing Record 455| sept-iles| Record 455 successfully processed.
# Processing Record 456| longyearbyen| Record 456 successfully processed.
# Processing Record 457| qesarya| Record 457 successfully processed.
# Processing Record 458| kisiwani| Record 458 successfully processed.
# Processing Record 459| saint anthony| Record 459 successfully processed.
# Processing Record 460| lozova| Record 460 successfully processed.
# Processing Record 461| klaksvik| Record 461 successfully processed.
# Processing Record 462| tucuma| tucuma not found or there was a problem with record #462. Skipping...
# Processing Record 463| dujuma| dujuma not found or there was a problem with record #463. Skipping...
# Processing Record 464| ponta delgada| Record 464 successfully processed.
# Processing Record 465| necochea| Record 465 successfully processed.
# Processing Record 466| panaba| Record 466 successfully processed.
# Processing Record 467| comodoro rivadavia| Record 467 successfully processed.
# Processing Record 468| husavik| Record 468 successfully processed.
# Processing Record 469| ondorhaan| ondorhaan not found or there was a problem with record #469. Skipping...
# Processing Record 470| jining| Record 470 successfully processed.
# Processing Record 471| lorengau| Record 471 successfully processed.
# Processing Record 472| camopi| Record 472 successfully processed.
# Processing Record 473| asyut| Record 473 successfully processed.
# Processing Record 474| meulaboh| Record 474 successfully processed.
# Processing Record 475| ashtian| Record 475 successfully processed.
# Processing Record 476| zenzeli| Record 476 successfully processed.
# Processing Record 477| corridonia| Record 477 successfully processed.
# Processing Record 478| ayr| Record 478 successfully processed.
# Processing Record 479| qaqortoq| Record 479 successfully processed.
# Processing Record 480| jizan| Record 480 successfully processed.
# Processing Record 481| nome| Record 481 successfully processed.
# Processing Record 482| mitsamiouli| Record 482 successfully processed.
# Processing Record 483| muzhi| Record 483 successfully processed.
# Processing Record 484| lithgow| Record 484 successfully processed.
# Processing Record 485| belaya gora| Record 485 successfully processed.
# Processing Record 486| nikolskoye| Record 486 successfully processed.
# Processing Record 487| port macquarie| Record 487 successfully processed.
# Processing Record 488| chatra| Record 488 successfully processed.
# Processing Record 489| dridu| Record 489 successfully processed.
# Processing Record 490| pyaozerskiy| Record 490 successfully processed.
# Processing Record 491| bethel| Record 491 successfully processed.
# Processing Record 492| port keats| Record 492 successfully processed.
# Processing Record 493| karkaralinsk| karkaralinsk not found or there was a problem with record #493. Skipping...
# Processing Record 494| de aar| Record 494 successfully processed.
# Processing Record 495| jyvaskyla| jyvaskyla not found or there was a problem with record #495. Skipping...
# Processing Record 496| bambanglipuro| Record 496 successfully processed.
# Processing Record 497| brae| Record 497 successfully processed.
# Processing Record 498| virginia beach| Record 498 successfully processed.
# Processing Record 499| buraydah| Record 499 successfully processed.
# Processing Record 500| egvekinot| Record 500 successfully processed.
# Processing Record 501| broome| Record 501 successfully processed.
# Processing Record 502| aginskoye| Record 502 successfully processed.
# Processing Record 503| jiayuguan| Record 503 successfully processed.
# Processing Record 504| alotau| alotau not found or there was a problem with record #504. Skipping...
# Processing Record 505| carnarvon| Record 505 successfully processed.
# Processing Record 506| kholodnyy| Record 506 successfully processed.
# Processing Record 507| wajid| Record 507 successfully processed.
# Processing Record 508| namibe| Record 508 successfully processed.
# Processing Record 509| nkhotakota| Record 509 successfully processed.
# Processing Record 510| dali| Record 510 successfully processed.
# Processing Record 511| novoagansk| Record 511 successfully processed.
# Processing Record 512| along| Record 512 successfully processed.
# Processing Record 513| pacific grove| Record 513 successfully processed.
# Processing Record 514| mawlaik| Record 514 successfully processed.
# Processing Record 515| gardez| Record 515 successfully processed.
# Processing Record 516| kabansk| Record 516 successfully processed.
# Processing Record 517| josanicka banja| Record 517 successfully processed.
# Processing Record 518| sokol| Record 518 successfully processed.
# Processing Record 519| vanavara| Record 519 successfully processed.
# Processing Record 520| doha| Record 520 successfully processed.
# Processing Record 521| batagay| Record 521 successfully processed.
# Processing Record 522| padang| Record 522 successfully processed.
# Processing Record 523| severo-kurilsk| Record 523 successfully processed.
# Processing Record 524| mahebourg| Record 524 successfully processed.
# Processing Record 525| zolotinka| zolotinka not found or there was a problem with record #525. Skipping...
# Processing Record 526| baymak| Record 526 successfully processed.
# Processing Record 527| quixada| quixada not found or there was a problem with record #527. Skipping...
# Processing Record 528| dzerzhinskoye| Record 528 successfully processed.
# Processing Record 529| teguldet| Record 529 successfully processed.
# Processing Record 530| marathon| Record 530 successfully processed.
# Processing Record 531| haicheng| Record 531 successfully processed.
# Processing Record 532| vengerovo| Record 532 successfully processed.
# Processing Record 533| bud| Record 533 successfully processed.
# Processing Record 534| eenhana| Record 534 successfully processed.
# Processing Record 535| laguna| Record 535 successfully processed.
# Processing Record 536| balkhash| Record 536 successfully processed.
# Processing Record 537| krasnoselkup| krasnoselkup not found or there was a problem with record #537. Skipping...
# Processing Record 538| zhezkazgan| Record 538 successfully processed.
# Processing Record 539| constitucion| Record 539 successfully processed.
# Processing Record 540| innisfail| Record 540 successfully processed.
# Processing Record 541| pangnirtung| Record 541 successfully processed.
# Processing Record 542| bowen| Record 542 successfully processed.
# Processing Record 543| vilhena| Record 543 successfully processed.
# Processing Record 544| gwanda| Record 544 successfully processed.
# Processing Record 545| puerto del rosario| Record 545 successfully processed.
# Processing Record 546| kingston| Record 546 successfully processed.
# Processing Record 547| kasongo-lunda| Record 547 successfully processed.
# Processing Record 548| matara| Record 548 successfully processed.
# Processing Record 549| ambon| Record 549 successfully processed.
# Processing Record 550| dzerzhinsk| Record 550 successfully processed.
# Processing Record 551| waitati| Record 551 successfully processed.
# Processing Record 552| oistins| Record 552 successfully processed.
# Processing Record 553| novyy urengoy| Record 553 successfully processed.
# Processing Record 554| cayenne| Record 554 successfully processed.
# Processing Record 555| stoyba| stoyba not found or there was a problem with record #555. Skipping...
# Processing Record 556| solnechnyy| Record 556 successfully processed.
# Processing Record 557| kathu| Record 557 successfully processed.
# Processing Record 558| uinskoye| Record 558 successfully processed.
# Processing Record 559| anadyr| Record 559 successfully processed.
# Processing Record 560| mpulungu| Record 560 successfully processed.
# Processing Record 561| guarumal| Record 561 successfully processed.
# Processing Record 562| agadez| Record 562 successfully processed.
# Processing Record 563| vavuniya| Record 563 successfully processed.
# Processing Record 564| ayorou| Record 564 successfully processed.
# Processing Record 565| chiang klang| Record 565 successfully processed.
# Processing Record 566| leh| Record 566 successfully processed.
# Processing Record 567| pandan niog| Record 567 successfully processed.
# Processing Record 568| bethanien| Record 568 successfully processed.
# Processing Record 569| don sak| Record 569 successfully processed.
# Processing Record 570| khirkiya| Record 570 successfully processed.
# Processing Record 571| mbanza-ngungu| Record 571 successfully processed.
# Processing Record 572| mariinskiy posad| Record 572 successfully processed.
# Processing Record 573| karasjok| Record 573 successfully processed.
# Processing Record 574| podyuga| Record 574 successfully processed.
# Processing Record 575| harper| Record 575 successfully processed.
# Processing Record 576| te anau| Record 576 successfully processed.
# Processing Record 577| ixtapa| Record 577 successfully processed.
# Processing Record 578| kontagora| Record 578 successfully processed.
# Processing Record 579| bargal| bargal not found or there was a problem with record #579. Skipping...
# Processing Record 580| bonthe| Record 580 successfully processed.
# Processing Record 581| urbano santos| Record 581 successfully processed.
# Processing Record 582| tecoanapa| Record 582 successfully processed.
# Processing Record 583| nanchong| Record 583 successfully processed.
# Processing Record 584| mahajanga| Record 584 successfully processed.
# Processing Record 585| muravlenko| Record 585 successfully processed.
# Processing Record 586| lenggries| Record 586 successfully processed.
# Processing Record 587| shchors| Record 587 successfully processed.
# Processing Record 588| arman| Record 588 successfully processed.
# Processing Record 589| jijiga| Record 589 successfully processed.
# Processing Record 590| talcahuano| Record 590 successfully processed.
# Processing Record 591| shimoda| Record 591 successfully processed.
# Processing Record 592| acari| Record 592 successfully processed.
# Processing Record 593| almeirim| Record 593 successfully processed.
# Processing Record 594| uruzgan| Record 594 successfully processed.
# Processing Record 595| baruun-urt| Record 595 successfully processed.
# Processing Record 596| pedasi| Record 596 successfully processed.
# Processing Record 597| manavgat| Record 597 successfully processed.
# Processing Record 598| sur| Record 598 successfully processed.
# Processing Record 599| nampa| Record 599 successfully processed.
# Processing Record 600| severnyy| severnyy not found or there was a problem with record #600. Skipping...
# Processing Record 601| riberalta| Record 601 successfully processed.
# Processing Record 602| imabari| imabari not found or there was a problem with record #602. Skipping...
# Processing Record 603| rehoboth| Record 603 successfully processed.
# Processing Record 604| aklavik| Record 604 successfully processed.
# Processing Record 605| bonga| Record 605 successfully processed.
# Processing Record 606| yakeshi| Record 606 successfully processed.
# Processing Record 607| great falls| Record 607 successfully processed.
# Processing Record 608| ramanuj ganj| Record 608 successfully processed.
# Processing Record 609| vestmanna| Record 609 successfully processed.
# Processing Record 610| tsuyama| Record 610 successfully processed.
# Processing Record 611| yairipok| Record 611 successfully processed.
# -----------------------------
# Data Retrieval Completed

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Convert retrieved data into a dataframe
df = pd.DataFrame(city_main_dict).T

#Convert numerical information stored as string data into actual numerical data into the dataframe
ser = list(df.columns)
ser.pop(0)
ser.pop(1)
ser.pop(1)
ser

for column in ser:
    df[column] = pd.to_numeric(df[column])

df.head(30)
# Out:
#                City  Cloudiness (%) Country                 Date  \
# 0         kununurra              88      AU  2019-Apr-7 10:30:00
# 1           tigzirt              92      DZ  2019-Apr-7 10:45:37
# 2           rikitea              56      PF  2019-Apr-7 10:46:20
# 3   arraial do cabo              75      BR  2019-Apr-7 10:00:00
# 4           mataura               0      NZ  2019-Apr-7 10:46:21
# 5           ushuaia              75      AR  2019-Apr-7 10:00:00
# 6      norman wells              20      CA  2019-Apr-7 10:00:00
# 7          hermanus               0      ZA  2019-Apr-7 10:45:31
# 8         busselton               0      AU  2019-Apr-7 10:45:14
# 9          pavlodar               0      KZ  2019-Apr-7 10:30:00
# 10            tiksi              12      RU  2019-Apr-7 10:46:26
# 11          talnakh              76      RU  2019-Apr-7 10:46:26
# 12       nouadhibou               0      MR  2019-Apr-7 10:00:00
# 13           torbay              90      CA  2019-Apr-7 10:46:22
# 15          dudinka              80      RU  2019-Apr-7 10:46:29
# 16             hilo              90      US  2019-Apr-7 10:45:17
# 17         tasiilaq              76      GL  2019-Apr-7 09:50:00
# 18          inyonga              12      TZ  2019-Apr-7 10:46:31
# 19   saint-philippe              90      CA  2019-Apr-7 10:45:31
# 21        caravelas              20      BR  2019-Apr-7 10:46:33
# 22           avarua              80      CK  2019-Apr-7 10:00:00
# 23            ginir               0      ET  2019-Apr-7 10:46:35
# 25        jamestown               0      AU  2019-Apr-7 10:43:20
# 26          kuching              75      MY  2019-Apr-7 10:30:00
# 27     madisonville              40      US  2019-Apr-7 10:46:36
# 29         jinchang              80      CN  2019-Apr-7 10:46:39
# 31     punta arenas              40      CL  2019-Apr-7 10:32:34
# 32           albany              90      US  2019-Apr-7 10:43:23
# 34          erenhot              36      CN  2019-Apr-7 10:46:42
# 36             chuy              36      UY  2019-Apr-7 10:46:43
#
#     Humidity (%)  Latitude  Longitude  Max Temperature (°F)  Wind Speed(mph)
# 0             62    -15.77     128.74                 86.00             4.70
# 1             60     36.57       4.20                 57.00             8.01
# 2            100    -23.12    -134.97                 76.77            11.32
# 3             83    -22.97     -42.02                 80.60            10.29
# 4             73    -46.19     168.86                 33.12             2.15
# 5             95    -54.81     -68.31                 35.60            24.16
# 6             92     65.28    -126.83                 15.80             5.82
# 7             60    -34.42      19.24                 82.00             8.01
# 8             40    -33.64     115.35                 64.00            17.81
# 9             24     52.28      76.96                 48.20            11.18
# 10            69     71.64     128.87                 21.25             8.52
# 11            84     69.49      88.39                 16.56             7.18
# 12            45     20.93     -17.03                 68.00            24.16
# 13            85     47.66     -52.73                 33.01             9.17
# 15            83     69.41      86.18                 16.92            14.00
# 16            88     19.71    -155.08                 69.80             4.70
# 17            63     65.61     -37.64                 30.20            39.15
# 18            44     -6.72      32.06                 86.85             5.95
# 19            93     45.36     -73.48                 39.99             6.93
# 21            95    -17.73     -39.27                 82.98            12.21
# 22            83    -21.21    -159.78                 77.00             3.36
# 23            26      7.14      40.71                 85.32             7.40
# 25            74    -33.21     138.60                 54.55             4.94
# 26            74      1.56     110.34                 87.01             3.36
# 27           100     37.33     -87.50                 61.00             5.73
# 29            72     38.52     102.19                 47.16             3.71
# 31            60    -53.16     -70.91                 41.00            11.41
# 32            86     42.65     -73.75                 39.99             2.15
# 34            33     43.65     111.97                 38.44             7.74
# 36            86    -33.69     -53.46                 66.33             7.29

# %%
#Confirm the data type on the columns of interest (Cloudiness, Humidity, Latitude, Longitude, Max Temp., and Wind Speed) are now numerical.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 551 entries, 0 to 610
# Data columns (total 9 columns):
# City                    551 non-null object
# Cloudiness (%)          551 non-null int64
# Country                 551 non-null object
# Date                    551 non-null object
# Humidity (%)            551 non-null int64
# Latitude                551 non-null float64
# Longitude               551 non-null float64
# Max Temperature (°F)    551 non-null float64
# Wind Speed(mph)         551 non-null float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 36.6+ KB

# %%
#Store the dataframe into a csv file
df.to_csv(output_data_file)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
#Stores the current date into a variable, to be used in the plots.
from datetime import datetime
date_today = datetime.today().strftime('%b-%d-%Y')

# %%
df.plot('Latitude', 'Max Temperature (°F)', 'Scatter', title = f'Max Temp (°F) vs Latitude {date_today}', grid = True)

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
df.plot('Latitude', 'Humidity (%)', 'Scatter', title = f'Max Temp (°F) vs Latitude {date_today}', grid = True)

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
df.plot('Latitude', 'Cloudiness (%)', 'Scatter', title = f'Max Temp (°F) vs Latitude {date_today}', grid = True)

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
df.plot('Latitude', 'Wind Speed(mph)', 'Scatter', grid = True)
