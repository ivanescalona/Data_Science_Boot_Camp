# %%
# Dependencies and Setup
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from scipy.stats import sem

# Hide warning messages in notebook
import warnings
warnings.filterwarnings('ignore')

# File to Load (Remember to Change These)
mouse_drug_data_to_load = "data/mouse_drug_data.csv"
clinical_trial_data_to_load = "data/clinicaltrial_data.csv"

# Read the Mouse and Drug Data and the Clinical Trial Data
mouse_df = pd.read_csv(mouse_drug_data_to_load)
clinical_df = pd.read_csv(clinical_trial_data_to_load)

# %%
# Combine the data into a single dataset

df = pd.merge(mouse_df, clinical_df , how = 'right', on = 'Mouse ID')

# %%
# Display the data table for preview
# df = df.set_index('Mouse ID')
df.head()
# Out:
#   Mouse ID      Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     f234  Stelasyn          0           45.000000                 0
# 1     f234  Stelasyn          5           47.313491                 0
# 2     f234  Stelasyn         10           47.904324                 0
# 3     f234  Stelasyn         15           48.735197                 1
# 4     f234  Stelasyn         20           51.112713                 2

# %% [markdown]
# ## Tumor Response to Treatment

# %%
df2 = df.loc[(df["Drug"] == 'Stelasyn') & (df['Timepoint'] == 5)]
df2.head()
# Out:
#    Mouse ID      Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 1      f234  Stelasyn          5           47.313491                 0
# 9      x402  Stelasyn          5           46.327570                 1
# 19     a492  Stelasyn          5           46.409143                 0
# 29     w540  Stelasyn          5           45.885370                 1
# 35     v764  Stelasyn          5           47.054185                 0

# %%
error = sem(df2.iloc[:, 3])
mean = df2.iloc[:, 3].mean()
print(error)
print(mean)
# Out:
# 0.2398624783049114
# 47.52745167414801

# %%
# Store the Mean Tumor Volume Data Grouped by Drug and Timepoint 
df1 = df.groupby(['Drug', 'Timepoint']).mean().drop(['Metastatic Sites'], axis = 1)


# Convert to DataFrame

# Preview DataFrame
df1.head()
# Out:
#                      Tumor Volume (mm3)
# Drug      Timepoint
# Capomulin 0                   45.000000
#           5                   44.266086
#           10                  43.084291
#           15                  42.064317
#           20                  40.716325

# %%
drugs = df["Drug"].unique()
time_point = df["Timepoint"].unique()
mean_std_error = dict()

for drug in drugs:
    for time in time_point:
        temp_df = df.loc[(df["Drug"] == drug) & (df['Timepoint'] == time)]
        error = sem(temp_df.iloc[:, 3])
        mean = temp_df.iloc[:, 3].mean()
        mean_std_error[(drug,time)] = (mean, error)

# %%
mean_std_error
# Out:
# {('Stelasyn', 0): (45.0, 0.0),
#  ('Stelasyn', 5): (47.52745167414801, 0.2398624783049114),
#  ('Stelasyn', 10): (49.46384376145653, 0.43367836020147604),
#  ('Stelasyn', 15): (51.52940872284348, 0.4932610701874855),
#  ('Stelasyn', 20): (54.06739490468571, 0.6218888449990556),
#  ('Stelasyn', 25): (56.16612328803685, 0.7419224971983612),
#  ('Stelasyn', 30): (59.826737600705556, 0.8995482081648019),
#  ('Stelasyn', 35): (62.44069946588751, 1.0031863245742614),
#  ('Stelasyn', 40): (65.356385975975, 1.4104351358543037),
#  ('Stelasyn', 45): (68.43831042955456, 1.5765560210916154),
#  ('Propriva', 0): (45.0, 0.0),
#  ('Infubinol', 40): (63.16282442327, 1.055219646713612),
#  ('Infubinol', 45): (65.75556227753334, 1.1444273834537741),
#  ('Ceftamin', 0): (45.0, 0.0),
#  ('Ceftamin', 5): (46.503050958038095, 0.1645048125327526),
#  ('Ceftamin', 10): (48.285125215944994, 0.23614441374948653),
#  ('Ceftamin', 15): (50.09405489174737, 0.33205282142132136),
#  ('Ceftamin', 20): (52.15704850437779, 0.359482397834251),
#  ('Ceftamin', 25): (54.28767405795, 0.4393562240933765),
#  ('Ceftamin', 30): (56.7695172102375, 0.4906202200341493),
#  ('Ceftamin', 35): (58.82754782648571, 0.6922475490241142),
#  ('Ceftamin', 40): (61.46789544553571, 0.7085051357294166),
#  ('Ceftamin', 45): (64.13242133515385, 0.902357697967584),
#  ('Zoniferol', 0): (45.0, 0.0),
#  ('Zoniferol', 5): (46.851818267095844, 0.1889503177270369),
#  ('Zoniferol', 10): (48.689881434709086, 0.26394944133066645),
#  ('Zoniferol', 15): (50.77905904982857, 0.37054440969618124),
#  ('Zoniferol', 20): (53.17033368935883, 0.5331823011300739),
#  ('Zoniferol', 25): (55.43293487386875, 0.6025128834155612),
#  ('Zoniferol', 30): (57.71353092456666, 0.8000426635768143),
#  ('Zoniferol', 35): (60.089372221321426, 0.8814257949671387),
#  ('Zoniferol', 40): (62.916691875571416, 0.9985151712078947),
#  ('Zoniferol', 45): (65.96088788929286, 1.0035757827899403),
#  ('Ramicane', 0): (45.0, 0.0),
#  ('Ramicane', 5): (43.944859399664004, 0.4829554747802227),
#  ('Ramicane', 10): (42.53195729572084, 0.7202246450310064),
#  ('Ramicane', 15): (41.4950609236625, 0.7704321755508987),
#  ('Ramicane', 20): (40.23832485764783, 0.786199470075371),
#  ('Ramicane', 25): (38.97429956154783, 0.7469914698233047),
#  ('Ramicane', 30): (38.703137337486964, 0.8649056558858257),
#  ('Ramicane', 35): (37.451996345295235, 0.9674333383274993),
#  ('Ramicane', 40): (36.574080675515, 1.1284453361613689),
#  ('Ramicane', 45): (34.955594791755, 1.226804987364093),
#  ('Placebo', 0): (45.0, 0.0),
#  ('Placebo', 5): (47.125589188437495, 0.2180907832521949),
#  ('Placebo', 10): (49.42332947868749, 0.40206380730509245),
#  ('Placebo', 15): (51.35974169802999, 0.6144614435805994),
#  ('Placebo', 20): (54.36441702681052, 0.8396091719248748),
#  ('Placebo', 25): (57.48257374394706, 1.0348719877946384),
#  ('Placebo', 30): (59.809063185673345, 1.2182311773334495),
#  ('Placebo', 35): (62.420615067964285, 1.2874806023058398),
#  ('Placebo', 40): (65.05267500425833, 1.3706340409784523),
#  ('Placebo', 45): (68.08408221741819, 1.3517255953502079)}

# %%
updated_mean_std_error = dict()

for i in range(0, len(df1)):
    for j in range(0, len(mean_std_error)):
        if (df1.index.values[i] == list(mean_std_error.keys())[j]):
            updated_mean_std_error[list(mean_std_error.keys())[j]] = list(mean_std_error.values())[j]
    
updated_mean_std_error
# Out:
#  ('Zoniferol', 20): (53.17033368935883, 0.5331823011300739),
#  ('Zoniferol', 25): (55.43293487386875, 0.6025128834155612),
#  ('Zoniferol', 30): (57.71353092456666, 0.8000426635768143),
#  ('Zoniferol', 35): (60.089372221321426, 0.8814257949671387),
#  ('Zoniferol', 40): (62.916691875571416, 0.9985151712078947),
#  ('Zoniferol', 45): (65.96088788929286, 1.0035757827899403)}

# %%
std_error = []
for i in range(0,len(updated_mean_std_error)):
    std_error.append(list(updated_mean_std_error.values())[i][1])

std_error
# Out:
# [0.0,
#  0.4485928502010375,
#  0.702684374523893,
#  0.838617247298569,
#  0.9097306924832056,
#  0.8816421535181785,
#  0.9344595100287,
#  1.0522408935958143,
#  1.2236083945982943,
#  1.2239774547199704,
#  0.0,
#  0.1645048125327526,
#  0.23614441374948653,
#  0.33205282142132136,
#  0.359482397834251,
#  0.4393562240933765,
#  0.4906202200341493,
#  0.6922475490241142,
#  0.7085051357294166,
#  0.902357697967584,
#  0.0,
#  0.23510230430767512,
#  0.28234591462157155,
#  0.3577050049753905,
#  0.4762095134790833,
#  0.5503145721542004,
#  0.6310610824580498,
#  0.9841549374017823,
#  1.055219646713612,
#  1.1444273834537741,
#  0.0,
#  0.2648185201672866,
#  0.35742125637213723,
#  0.5802679659678779,
#  0.7264838239834724,
#  0.755412752891038,
#  0.9341208698545591,
#  1.1278671755166152,
#  1.1584488850098997,
#  1.453186475842581,
#  0.0,
#  0.20238536264761797,
#  0.31941505760056205,
#  0.44437783748790144,
#  0.5952601862606292,
#  0.8137064624708964,
#  0.975496251401448,
#  1.0137686743565264,
#  1.118567411072631,
#  1.4163632702920153,
#  0.0,
#  0.2180907832521949,
#  0.40206380730509245,
#  0.6144614435805994,
#  0.8396091719248748,
#  1.0348719877946384,
#  1.2182311773334495,
#  1.2874806023058398,
#  1.3706340409784523,
#  1.3517255953502079,
#  0.0,
#  0.23170801872962143,
#  0.3761947948300582,
#  0.4661093725230648,
#  0.5551809305748974,
#  0.5774012175389455,
#  0.7460445397968312,
#  1.0849292068264047,
#  1.564779050518981,
#  1.8885856555955391,
#  0.0,
#  0.4829554747802227,
#  0.7202246450310064,
#  0.7704321755508987,
#  0.786199470075371,
#  0.7469914698233047,
#  0.8649056558858257,
#  0.9674333383274993,
#  1.1284453361613689,
#  1.226804987364093,
#  0.0,
#  0.2398624783049114,
#  0.43367836020147604,
#  0.4932610701874855,
#  0.6218888449990556,
#  0.7419224971983612,
#  0.8995482081648019,
#  1.0031863245742614,
#  1.4104351358543037,
#  1.5765560210916154,
#  0.0,
#  0.1889503177270369,
#  0.26394944133066645,
#  0.37054440969618124,
#  0.5331823011300739,
#  0.6025128834155612,
#  0.8000426635768143,
#  0.8814257949671387,
#  0.9985151712078947,
#  1.0035757827899403]

# %%
df1['Standard Error'] = std_error
df1.head(3)
# Out:
#                      Tumor Volume (mm3)  Standard Error
# Drug      Timepoint
# Capomulin 0                   45.000000        0.000000
#           5                   44.266086        0.448593
#           10                  43.084291        0.702684

# %%
# Store the Standard Error of Tumor Volumes Grouped by Drug and Timepoint

# Convert to DataFrame

# Preview DataFrame

# %%
df4 = df1.drop(['Standard Error'], axis = 1)
df5 = df4.swaplevel().unstack()

# %%
df5
# Out:
#           Tumor Volume (mm3)                                              \
# Drug               Capomulin   Ceftamin  Infubinol   Ketapril   Naftisol
# Timepoint
# 0                  45.000000  45.000000  45.000000  45.000000  45.000000
# 5                  44.266086  46.503051  47.062001  47.389175  46.796098
# 10                 43.084291  48.285125  49.403909  49.582269  48.694210
# 15                 42.064317  50.094055  51.296397  52.399974  50.933018
# 20                 40.716325  52.157049  53.197691  54.920935  53.644087
# 25                 39.939528  54.287674  55.715252  57.678982  56.731968
# 30                 38.769339  56.769517  58.299397  60.994507  59.559509
# 35                 37.816839  58.827548  60.742461  63.371686  62.685087
# 40                 36.958001  61.467895  63.162824  66.068580  65.600754
# 45                 36.236114  64.132421  65.755562  70.662958  69.265506
#
#
# Drug         Placebo   Propriva   Ramicane   Stelasyn  Zoniferol
# Timepoint
# 0          45.000000  45.000000  45.000000  45.000000  45.000000
# 5          47.125589  47.248967  43.944859  47.527452  46.851818
# 10         49.423329  49.101541  42.531957  49.463844  48.689881
# 15         51.359742  51.067318  41.495061  51.529409  50.779059
# 20         54.364417  53.346737  40.238325  54.067395  53.170334
# 25         57.482574  55.504138  38.974300  56.166123  55.432935
# 30         59.809063  58.196374  38.703137  59.826738  57.713531
# 35         62.420615  60.350199  37.451996  62.440699  60.089372
# 40         65.052675  63.045537  36.574081  65.356386  62.916692
# 45         68.084082  66.258529  34.955595  68.438310  65.960888

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview that Reformatting worked

# %%
drugs_df5 = list(df5.columns)
error_dict = dict()

for i in range(0,10):
    temp_list = []
    for j in range(i*10,(i+1)*10):
         temp_list.append(std_error[j])
    error_dict[drugs_df5[i][1]] = temp_list
error_dict
# Out:
# {'Capomulin': [0.0,
#   0.4485928502010375,
#   0.702684374523893,
#   0.838617247298569,
#   0.9097306924832056,
#   0.8816421535181785,
#   0.9344595100287,
#   1.0522408935958143,
#   1.2236083945982943,
#   1.2239774547199704],
#  'Ceftamin': [0.0,
#   0.1645048125327526,
#   0.23614441374948653,
#   0.33205282142132136,
#   0.359482397834251,
#   0.4393562240933765,
#   0.4906202200341493,
#   0.6922475490241142,
#   0.7085051357294166,
#   0.902357697967584],
#  'Infubinol': [0.0,
#   0.23510230430767512,
#   0.28234591462157155,
#   0.3577050049753905,
#   0.4762095134790833,
#   0.5503145721542004,
#   0.6310610824580498,
#   0.9841549374017823,
#   1.055219646713612,
#   1.1444273834537741],
#  'Ketapril': [0.0,
#   0.2648185201672866,
#   0.35742125637213723,
#   0.5802679659678779,
#   0.7264838239834724,
#   0.755412752891038,
#   0.9341208698545591,
#   1.1278671755166152,
#   1.1584488850098997,
#   1.453186475842581],
#  'Naftisol': [0.0,
#   0.20238536264761797,
#   0.31941505760056205,
#   0.44437783748790144,
#   0.5952601862606292,
#   0.8137064624708964,
#   0.975496251401448,
#   1.0137686743565264,
#   1.118567411072631,
#   1.4163632702920153],
#  'Placebo': [0.0,
#   0.2180907832521949,
#   0.40206380730509245,
#   0.6144614435805994,
#   0.8396091719248748,
#   1.0348719877946384,
#   1.2182311773334495,
#   1.2874806023058398,
#   1.3706340409784523,
#   1.3517255953502079],
#  'Propriva': [0.0,
#   0.23170801872962143,
#   0.3761947948300582,
#   0.4661093725230648,
#   0.5551809305748974,
#   0.5774012175389455,
#   0.7460445397968312,
#   1.0849292068264047,
#   1.564779050518981,
#   1.8885856555955391],
#  'Ramicane': [0.0,
#   0.4829554747802227,
#   0.7202246450310064,
#   0.7704321755508987,
#   0.786199470075371,
#   0.7469914698233047,
#   0.8649056558858257,
#   0.9674333383274993,
#   1.1284453361613689,
#   1.226804987364093],
#  'Stelasyn': [0.0,
#   0.2398624783049114,
#   0.43367836020147604,
#   0.4932610701874855,
#   0.6218888449990556,
#   0.7419224971983612,
#   0.8995482081648019,
#   1.0031863245742614,
#   1.4104351358543037,
#   1.5765560210916154],
#  'Zoniferol': [0.0,
#   0.1889503177270369,
#   0.26394944133066645,
#   0.37054440969618124,
#   0.5331823011300739,
#   0.6025128834155612,
#   0.8000426635768143,
#   0.8814257949671387,
#   0.9985151712078947,
#   1.0035757827899403]}

# %%
# Generate the Plot (with Error Bars)
studied_drugs = ['Capomulin', 'Infubinol', 'Ketapril', 'Placebo']
x_axis = time_point
color = ['red', 'blue', 'green', 'black']
cnt = 0

fig = plt.figure()
fig.set_figheight(8)
fig.set_figwidth(11)

for drug in studied_drugs:
    for i in range(0,len(error_dict)):
        if (list(error_dict.keys())[i] == drug):
            plt.errorbar(x_axis, df5['Tumor Volume (mm3)'][drug], yerr = error_dict[drug], fmt = 'none', ecolor=color[cnt], capsize = 3, elinewidth=.8)
            cnt = cnt + 1


plt.xlabel('Timepoint (Days)')
plt.ylabel(r'Tumor Volume mm$^{3}$')
plt.title(r'Tumor Volume mm$^{3}$ vs Timepoint series')



plt.plot(x_axis, df5['Tumor Volume (mm3)']['Capomulin'], 'r:o', linewidth = 0.8)
plt.plot(x_axis, df5['Tumor Volume (mm3)']['Infubinol'], 'b:^', linewidth = 0.8)
plt.plot(x_axis, df5['Tumor Volume (mm3)']['Ketapril'], 'g:s', linewidth = 0.8)
plt.plot(x_axis, df5['Tumor Volume (mm3)']['Placebo'], 'k:D', linewidth = 0.8)
plt.legend(labels = studied_drugs)

plt.grid()
# Show the Figure

# Save the Figure
plt.savefig('tumorvolume.png')

# %% [markdown]
# ## Metastatic Response to Treatment

# %%
# Store the Mean Met. Site Data Grouped by Drug and Timepoint 

# Convert to DataFrame
df6 = df.groupby(['Drug', 'Timepoint']).mean().drop(['Tumor Volume (mm3)'], axis = 1)
# Preview DataFrame
df6.head()
# Out:
#                      Metastatic Sites
# Drug      Timepoint
# Capomulin 0                  0.000000
#           5                  0.160000
#           10                 0.320000
#           15                 0.375000
#           20                 0.652174

# %%
drugs = df["Drug"].unique()
time_point = df["Timepoint"].unique()
met_mean_std_error = dict()

for drug in drugs:
    for time in time_point:
        temp_df = df.loc[(df["Drug"] == drug) & (df['Timepoint'] == time)]
        error = sem(temp_df.iloc[:, 4])
        mean = temp_df.iloc[:, 4].mean()
        met_mean_std_error[(drug,time)] = (mean, error)

# %%
met_updated_mean_std_error = dict()

for i in range(0, len(df6)):
    for j in range(0, len(met_mean_std_error)):
        if (df6.index.values[i] == list(met_mean_std_error.keys())[j]):
            met_updated_mean_std_error[list(met_mean_std_error.keys())[j]] = list(met_mean_std_error.values())[j]

# %%
met_std_error = []
for i in range(0,len(met_updated_mean_std_error)):
    met_std_error.append(list(met_updated_mean_std_error.values())[i][1])

# %%
df6['Standard Error'] = std_error
df6.head(3)
# Out:
#                      Metastatic Sites  Standard Error
# Drug      Timepoint
# Capomulin 0                      0.00        0.000000
#           5                      0.16        0.448593
#           10                     0.32        0.702684

# %%
# Store the Standard Error associated with Met. Sites Grouped by Drug and Timepoint 

# Convert to DataFrame

# Preview DataFrame

# %%
df7 = df6.drop(['Standard Error'], axis = 1)
df8 = df7.swaplevel().unstack()
df8
# Out:
#           Metastatic Sites                                                    \
# Drug             Capomulin  Ceftamin Infubinol  Ketapril  Naftisol   Placebo
# Timepoint
# 0                 0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# 5                 0.160000  0.380952  0.280000  0.304348  0.260870  0.375000
# 10                0.320000  0.600000  0.666667  0.590909  0.523810  0.833333
# 15                0.375000  0.789474  0.904762  0.842105  0.857143  1.250000
# 20                0.652174  1.111111  1.050000  1.210526  1.150000  1.526316
# 25                0.818182  1.500000  1.277778  1.631579  1.500000  1.941176
# 30                1.090909  1.937500  1.588235  2.055556  2.066667  2.266667
# 35                1.181818  2.071429  1.666667  2.294118  2.266667  2.642857
# 40                1.380952  2.357143  2.100000  2.733333  2.466667  3.166667
# 45                1.476190  2.692308  2.111111  3.363636  2.538462  3.272727
#
#
# Drug       Propriva  Ramicane  Stelasyn Zoniferol
# Timepoint
# 0          0.000000  0.000000  0.000000  0.000000
# 5          0.320000  0.120000  0.240000  0.166667
# 10         0.565217  0.250000  0.478261  0.500000
# 15         0.764706  0.333333  0.782609  0.809524
# 20         1.000000  0.347826  0.952381  1.294118
# 25         1.357143  0.652174  1.157895  1.687500
# 30         1.615385  0.782609  1.388889  1.933333
# 35         2.300000  0.952381  1.562500  2.285714
# 40         2.777778  1.100000  1.583333  2.785714
# 45         2.571429  1.250000  1.727273  3.071429

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview that Reformatting worked

# %%
drugs_df5 = list(df5.columns)
met_error_dict = dict()

for i in range(0,10):
    temp_list = []
    for j in range(i*10,(i+1)*10):
         temp_list.append(met_std_error[j])
    met_error_dict[drugs_df5[i][1]] = temp_list

# %%
studied_drugs = ['Capomulin', 'Infubinol', 'Ketapril', 'Placebo']
x_axis = time_point
color = ['red', 'blue', 'green', 'black']
cnt = 0

fig = plt.figure()
fig.set_figheight(8)
fig.set_figwidth(11)

for drug in studied_drugs:
    for i in range(0,len(met_error_dict)):
        if (list(met_error_dict.keys())[i] == drug):
            plt.errorbar(x_axis, df8['Metastatic Sites'][drug], yerr = error_dict[drug], fmt = 'none', ecolor=color[cnt], capsize = 3, elinewidth=.8)
            cnt = cnt + 1

plt.xlabel('Timepoint (Days)')
plt.ylabel(r'Metastatic Sites')
plt.title(r'Metastatic Sites vs Timepoint series')
plt.legend(labels = studied_drugs)

plt.plot(x_axis, df8['Metastatic Sites']['Capomulin'],'r:o', linewidth = 0.8)
plt.plot(x_axis, df8['Metastatic Sites']['Infubinol'], 'b:^', linewidth = 0.8)
plt.plot(x_axis, df8['Metastatic Sites']['Ketapril'], 'g:s', linewidth = 0.8)
plt.plot(x_axis, df8['Metastatic Sites']['Placebo'], 'k:D', linewidth = 0.8)
plt.grid()

# Show the Figure

# Save the Figure
plt.savefig('metastaticsites.png')

# %% [markdown]
# ## Survival Rates

# %%
# Store the Count of Mice Grouped by Drug and Timepoint (W can pass any metric)

# Convert to DataFrame

# Preview DataFrame

# %%
df.head()
# Out:
#   Mouse ID      Drug  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     f234  Stelasyn          0           45.000000                 0
# 1     f234  Stelasyn          5           47.313491                 0
# 2     f234  Stelasyn         10           47.904324                 0
# 3     f234  Stelasyn         15           48.735197                 1
# 4     f234  Stelasyn         20           51.112713                 2

# %%
df9 = df.groupby(['Drug', 'Timepoint']).count().drop(['Metastatic Sites', 'Tumor Volume (mm3)'], axis = 1)
df9.head()
# Out:
#                      Mouse ID
# Drug      Timepoint
# Capomulin 0                25
#           5                25
#           10               25
#           15               24
#           20               23

# %%
df10 = df9['Mouse ID'].swaplevel().unstack()
df10.head()
# Out:
# Drug       Capomulin  Ceftamin  Infubinol  Ketapril  Naftisol  Placebo  \
# Timepoint
# 0                 25        25         25        25        25       25
# 5                 25        21         25        23        23       24
# 10                25        20         21        22        21       24
# 15                24        19         21        19        21       20
# 20                23        18         20        19        20       19
#
# Drug       Propriva  Ramicane  Stelasyn  Zoniferol
# Timepoint
# 0                26        25        26         25
# 5                25        25        25         24
# 10               23        24        23         22
# 15               17        24        23         21
# 20               17        23        21         17

# %%
# Minor Data Munging to Re-Format the Data Frames

# Preview the Data Frame

# %%
studied_drugs = ['Capomulin', 'Infubinol', 'Ketapril', 'Placebo']
x_axis = time_point

fig = plt.figure()
fig.set_figheight(8)
fig.set_figwidth(11)

plt.xlabel('Timepoint (Days)')
plt.ylabel(r'Survival Rate')
plt.title(r'Metastatic Sites vs Timepoint series')


plt.plot(x_axis, df10['Capomulin']*4,'r:o', linewidth = 0.8)
plt.plot(x_axis, df10['Infubinol']*4, 'b:^', linewidth = 0.8)
plt.plot(x_axis, df10['Ketapril']*4, 'g:s', linewidth = 0.8)
plt.plot(x_axis, df10['Placebo']*4, 'k:D', linewidth = 0.8)
plt.grid()
plt.legend(labels = studied_drugs, loc = 3)
# Show the Figure

# Save the Figure
plt.savefig('survival.png')

# %%
# Generate the Plot (Accounting for percentages)

# Save the Figure

# Show the Figure

# %%
# Out:
# Timepoint
# 0     45.000000
# 5     47.125589
# 10    49.423329
# 15    51.359742
# 20    54.364417
# 25    57.482574
# 30    59.809063
# 35    62.420615
# 40    65.052675
# 45    68.084082
# Name: Placebo, dtype: float64

# %% [markdown]
# ## Summary Bar Graph

# %%
# Calculate the percent changes for each drug

timepoint = list(df5.index)
drugs = list(df5.columns)

for item in drugs:
    temp = drugs.pop(0)
    drugs.append(temp[1])

print(drugs)    
    
summary_dict = dict()
for drug in drugs: 
    init = list(df5['Tumor Volume (mm3)'][drug])[0]
    final = list(df5['Tumor Volume (mm3)'][drug])[-1]
    percent = (init-final)*100/init
    summary_dict[drug] = percent

# Display the data to confirm
summary_dict
# Out:
# ['Capomulin', 'Ceftamin', 'Infubinol', 'Ketapril', 'Naftisol', 'Placebo', 'Propriva', 'Ramicane', 'Stelasyn', 'Zoniferol']
# {'Capomulin': 19.475302667894173,
#  'Ceftamin': -42.51649185589744,
#  'Infubinol': -46.12347172785188,
#  'Ketapril': -57.028794686606076,
#  'Naftisol': -53.92334713476923,
#  'Placebo': -51.29796048315153,
#  'Propriva': -47.24117486320637,
#  'Ramicane': 22.320900462766673,
#  'Stelasyn': -52.08513428789903,
#  'Zoniferol': -46.57975086509525}

# %%
my_tuple_drugs = tuple(list(summary_dict.keys()))
my_tuple_percent = tuple(list(summary_dict.values()))

drugs_series = pd.Series(my_tuple_drugs)
drugs_df = pd.DataFrame(drugs_series, columns = ['Drugs'])


percent_series = pd.Series(my_tuple_percent)
percent_df = pd.DataFrame(percent_series, columns = ['Percent Change'])
percent_df

summary_df = drugs_df
summary_df['Percent Change'] = percent_df['Percent Change']
summary_df
# Out:
#        Drugs  Percent Change
# 0  Capomulin       19.475303
# 1   Ceftamin      -42.516492
# 2  Infubinol      -46.123472
# 3   Ketapril      -57.028795
# 4   Naftisol      -53.923347
# 5    Placebo      -51.297960
# 6   Propriva      -47.241175
# 7   Ramicane       22.320900
# 8   Stelasyn      -52.085134
# 9  Zoniferol      -46.579751

# %%
# Out:
#        Drugs  Percent Change
# 0  Capomulin       19.475303

# %%
for drug in studied_drugs:
    temp_df = summary_df.loc[summary_df['Drugs'] == drug]
    temp_percent = float(temp_df['Percent Change'])*-1
    if ( temp_percent > 0 ):
        color = 'green'
        sign = 1
    else: 
        color = 'red'
        sign = -1
    plt.bar(drug, temp_percent, color = color, width=1.0, edgecolor = 'white')
    plt.text(drug, sign*6, str(round(temp_percent)) + '%', horizontalalignment='center', color='white', weight = 'bold')


plt.grid()

# %%
# Store all Relevant Percent Changes into a Tuple


# Splice the data between passing and failing drugs




# Orient widths. Add labels, tick marks, etc. 


# Use functions to label the percentages of changes


# Call functions to implement the function calls


# Save the Figure


# Show the Figure
fig.show()
